# %% [markdown]
# <a href="https://colab.research.google.com/github/kaustubhh-source/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kaustubhh-source/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# Task Type: Binary Classification.
#
# Why: We are framing the core problem as a classification challenge. Instead of predicting raw query numbers, the system classifies whether a specific search topic's trajectory will encounter an upcoming high-velocity breakout/anomaly (1) or maintain typical, stable baseline activity (0).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# Target Variable: is_anomalous_surgeWhere it comes from: It is an engineered binary proxy column derived from a mathematical rule. A row is flagged as 1 if the observed weekly search volume shifts by more than $2.5$ standard deviations above its rolling historical regional baseline, and 0 otherwise.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# Success Metric: Precision@K (specifically Precision@50).What number means 'good': A metric of Precision@50 $\ge$ 85% is our benchmark for a high-quality model. Since public health deployment teams have limited manual bandwidth, we must prioritize minimizing False Alerts. When the system highlights the top 50 highest-risk search clusters, at least 42 of them must be genuine anomalies to maintain user trust.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# Unit of Analysis: A region-week-topic observation window.
# One row represents the aggregated search metrics and environmental features for a single query category over a one-week duration inside a specific tracking region.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import subprocess
import pandas as pd

# Re-verify repo content downloads properly into Colab workspace
REPO_DIR = "flyrank-ml-internship-starter"
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

# Read the starter dataframe file
csv_path = os.path.join(REPO_DIR, "data/raw/content_refresh_anonymized.csv")
df = pd.read_csv(csv_path)

# Establish our custom target classification flag for simulation
df["is_anomalous_surge"] = (df["ctr"] > 0.35).astype(int)

# Display clean unit slices
print("--- Target Matrix Slices ---")
print(df[["position_tier", "search_volume", "ctr", "is_anomalous_surge"]].head(8))
print(f"\nParsed DataFrame Rows Count: {len(df):,}")
# Out:
# --- Target Matrix Slices ---
#   position_tier  search_volume   ctr  is_anomalous_surge
# 0      striking           10.0  0.76                   1
# 1      page_3_5           90.0  0.05                   0
# 2      page_3_5            0.0  0.09                   0
# 3        page_1           10.0  0.49                   1
# 4      page_3_5            0.0  0.13                   0
# 5        page_1          720.0  0.03                   0
# 6        page_1            0.0  0.00                   0
# 7      page_3_5          590.0  0.06                   0
#
# Parsed DataFrame Rows Count: 30,000

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# Why ML Beats Rules: Simple heuristic if-statements (like if search_volume > 2000) completely fall apart in production. Baseline health query traffic scales non-linearly between large metropolitan centers and small rural districts. Furthermore, standard rules cannot easily factor in complex lag interactions, regional humidity variations, and historical seasonality shifts simultaneously. Machine Learning dynamically maps these multi-variable cross-dependencies to ensure tracking accuracy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

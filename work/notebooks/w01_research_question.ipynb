# %% [markdown]
# <a href="https://colab.research.google.com/github/kaustubhh-source/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kaustubhh-source/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# My Lane: Freestyle (Foundational Framework for ViralWell)
#
# Why this one: I am pursuing a freestyle lane to lay the analytical foundation for my capstone project, ViralWell, which is a climate-driven predictive health analytics web application. This lane allows me to explore how seasonal, environmental, and climate factors directly correlate with shifts in user search behaviors and health-related query trends. Understanding these signals is essential to building an early-warning system that bridges environmental anomalies with public health trends.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The Research Question:
# To what extent can we predict anomalies in regional search volumes for infectious/seasonal health queries using localized temperature, precipitation patterns, and historical search cycles?
#
# The Decision: Improving the logistical and stocking decisions of local pharmacies, clinics, and regional public health departments.
#
# Who acts on it: Public health administrators, medical inventory managers, and community clinic coordinators.
#
# Cost of a wrong call:
#
# False Positive (Predicting an outbreak that doesn't happen): Minor logistics costs due to holding excess medical supplies or diagnostic kits.
#
# False Negative (Failing to predict a surge): Severe public health consequences, including critical supply shortages (medications, masks, test kits), overwhelmed clinics, and delayed medical interventions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os
import subprocess
import pandas as pd

# 1. Pull the repository files back into Colab's workspace if the session reset
REPO_DIR = "flyrank-ml-internship-starter"
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"

if not os.path.isdir(REPO_DIR):
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)

# 2. Load the starter CSV file
csv_path = os.path.join(REPO_DIR, "data/raw/content_refresh_anonymized.csv")
df = pd.read_csv(csv_path)

# 3. Calculate 3 support numbers
total_queries = len(df)
declining_queries = len(df[df["trend_direction"] == "down"])
average_volume = df["search_volume"].mean()

print(f"Total queries analyzed: {total_queries:,}")
print(f"Queries with declining search trends: {declining_queries:,} ({declining_queries/total_queries:.1%})")
print(f"Baseline average search volume: {average_volume:.2f}")
# Out:
# Total queries analyzed: 30,000
# Queries with declining search trends: 16,262 (54.2%)
# Baseline average search volume: 158.88

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What I can claim: I can claim to identify observational and directional correlations between environmental/seasonal indicators and health-seeking search patterns. The model serves strictly as a decision-support utility to highlight geographical areas showing higher probabilities of upcoming search surges.
#
# What I cannot claim: I can never claim causal proof (e.g., "climate change directly caused this specific Google query to rise"). I will not claim to predict Google's private search algorithms or guarantee real-world viral transmission rates.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
